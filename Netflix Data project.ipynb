# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data =pd.read_csv(r'C:\Users\SH2\Downloads\8. Netflix Dataset.csv',index_col ='Show_Id')

# %%
data.head()
# Out:
#         Category  Title           Director  \
# Show_Id
# s1       TV Show     3%                NaN
# s2         Movie  07:19  Jorge Michel Grau
# s3         Movie  23:59       Gilbert Chan
# s4         Movie      9        Shane Acker
# s5         Movie     21     Robert Luketic
#
#                                                       Cast        Country  \
# Show_Id
# s1       João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# s2       Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# s3       Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# s4       Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# s5       Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#               Release_Date Rating   Duration  \
# Show_Id
# s1         August 14, 2020  TV-MA  4 Seasons
# s2       December 23, 2016  TV-MA     93 min
# s3       December 20, 2018      R     78 min
# ...

# %%
data.shape
# Out:
# (7789, 10)

# %%
data.size # total number of elements in the dataset
# Out:
# 77890

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7789 entries, s1 to s7787
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Category      7789 non-null   object
#  1   Title         7789 non-null   object
#  2   Director      5401 non-null   object
#  3   Cast          7071 non-null   object
#  4   Country       7282 non-null   object
#  5   Release_Date  7779 non-null   object
#  6   Rating        7782 non-null   object
#  7   Duration      7789 non-null   object
#  8   Type          7789 non-null   object
#  9   Description   7789 non-null   object
# dtypes: object(10)
# memory usage: 669.4+ KB

# %%
# duplicate function() 
data[data.duplicated()]
# Out:
#         Category              Title        Director  \
# Show_Id
# s684       Movie           Backfire     Dave Patten
# s6621      Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                       Cast        Country  \
# Show_Id
# s684     Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# s6621    Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#               Release_Date Rating Duration  \
# Show_Id
# s684         April 5, 2019  TV-MA   97 min
# s6621    September 4, 2020  TV-MA   94 min
#
#                                           Type  \
# Show_Id
# s684     Dramas, Independent Movies, Thrillers
# s6621     Comedies, Dramas, Independent Movies
#
#                                                Description
# Show_Id
# s684     When two would-be robbers accidentally kill a ...
# s6621    A disillusioned security guard transforms into...

# %%
data.shape
# Out:
# (7789, 10)

# %%
data.drop_duplicates(inplace =True)

# %%
data.shape ## two rows deleted from the dataset
# Out:
# (7787, 10)

# %% [markdown]
# ## isnull()

# %%
data.isnull().sum()
# Out:
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:ylabel='Show_Id'>

# %%
data.drop(columns =['Director'] ,inplace =True)

# %%
data.head()
# Out:
#         Category  Title                                               Cast  \
# Show_Id
# s1       TV Show     3%  João Miguel, Bianca Comparato, Michel Gomes, R...
# s2         Movie  07:19  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# s3         Movie  23:59  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# s4         Movie      9  Elijah Wood, John C. Reilly, Jennifer Connelly...
# s5         Movie     21  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
#
#                Country       Release_Date Rating   Duration  \
# Show_Id
# s1              Brazil    August 14, 2020  TV-MA  4 Seasons
# s2              Mexico  December 23, 2016  TV-MA     93 min
# s3           Singapore  December 20, 2018      R     78 min
# s4       United States  November 16, 2017  PG-13     80 min
# s5       United States    January 1, 2020  PG-13    123 min
#
#                                                       Type  \
# Show_Id
# s1       International TV Shows, TV Dramas, TV Sci-Fi &...
# ...

# %%
data.columns
# Out:
# Index(['Category', 'Title', 'Cast', 'Country', 'Release_Date', 'Rating',
#        'Duration', 'Type', 'Description'],
#       dtype='object')

# %% [markdown]
# ### for House of card what is Show Id and who is the director of the show

# %%
data[data['Title'].isin(['House of Cards'])]
# Out:
#         Category           Title  \
# Show_Id
# s2833    TV Show  House of Cards
#
#                                                       Cast        Country  \
# Show_Id
# s2833    Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#              Release_Date Rating   Duration                     Type  \
# Show_Id
# s2833    November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                                Description
# Show_Id
# s2833    A ruthless politician will stop at nothing to ...

# %%
data[data.Title.str.contains('House of Cards')]
# Out:
#         Category           Title  \
# Show_Id
# s2833    TV Show  House of Cards
#
#                                                       Cast        Country  \
# Show_Id
# s2833    Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#              Release_Date Rating   Duration                     Type  \
# Show_Id
# s2833    November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                                Description
# Show_Id
# s2833    A ruthless politician will stop at nothing to ...

# %%
data['date-n'] = pd.to_datetime(data['Release_Date'])

# %%
data.head()
# Out:
#         Category  Title                                               Cast  \
# Show_Id
# s1       TV Show     3%  João Miguel, Bianca Comparato, Michel Gomes, R...
# s2         Movie  07:19  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# s3         Movie  23:59  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# s4         Movie      9  Elijah Wood, John C. Reilly, Jennifer Connelly...
# s5         Movie     21  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
#
#                Country       Release_Date Rating   Duration  \
# Show_Id
# s1              Brazil    August 14, 2020  TV-MA  4 Seasons
# s2              Mexico  December 23, 2016  TV-MA     93 min
# s3           Singapore  December 20, 2018      R     78 min
# s4       United States  November 16, 2017  PG-13     80 min
# s5       United States    January 1, 2020  PG-13    123 min
#
#                                                       Type  \
# Show_Id
# s1       International TV Shows, TV Dramas, TV Sci-Fi &...
# ...

# %%
## In which year  is highest number on Tv shown & movies were released
data['date-n'].dt.year.value_counts() # value counts counts number of all individuals years
# Out:
# 2019.0    2153
# 2020.0    2009
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2008.0       2
# 2009.0       2
# 2010.0       1
# Name: date-n, dtype: int64

# %%
plt.figure(figsize=(12,8))
data['date-n'].dt.year.value_counts().plot(kind='bar')
plt.xlabel('Year',size =20)
plt.ylabel('Number of release movies',size=20)
plt.title('Number of released movies per year' ,size =20)
# Out:
# Text(0.5, 1.0, 'Number of released movies per year')

# %%
plt.figure(figsize =(12,8))
sns.lineplot(data =data['date-n'].dt.year.value_counts())
# Out:
# <AxesSubplot:ylabel='date-n'>

# %%
data.groupby('Category').Category.count()
# Out:
# Category
# Movie      5377
# TV Show    2410
# Name: Category, dtype: int64

# %%
sns.countplot(data['Category'])
# Out:
# C:\Users\SH2\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Category', ylabel='count'>

# %%
# creating a new column
data['year'] =data['date-n'].dt.year

# %%
data.head()
# Out:
#         Category  Title                                               Cast  \
# Show_Id
# s1       TV Show     3%  João Miguel, Bianca Comparato, Michel Gomes, R...
# s2         Movie  07:19  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# s3         Movie  23:59  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# s4         Movie      9  Elijah Wood, John C. Reilly, Jennifer Connelly...
# s5         Movie     21  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
#
#                Country       Release_Date Rating   Duration  \
# Show_Id
# s1              Brazil    August 14, 2020  TV-MA  4 Seasons
# s2              Mexico  December 23, 2016  TV-MA     93 min
# s3           Singapore  December 20, 2018      R     78 min
# s4       United States  November 16, 2017  PG-13     80 min
# s5       United States    January 1, 2020  PG-13    123 min
#
#                                                       Type  \
# Show_Id
# s1       International TV Shows, TV Dramas, TV Sci-Fi &...
# ...

# %%
## finding all movies that released in 2020
data[(data['Category'] =='Movie') & (data['year']==2020.0)]['Title']
# Out:
# Show_Id
# s5                                            21
# s7                                           122
# s15                                         3022
# s28                                       #Alive
# s29                #AnneFrank - Parallel Stories
#                           ...
# s7761                                  Zaki Chan
# s7782                                       Zoom
# s7783                                       Zozo
# s7785                          Zulu Man in Japan
# s7787    ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
# Name: Title, Length: 1312, dtype: object

# %%
## show only the titles of all tv movies show in only Egypt 
data[(data['Country'] =='Egypt') & (data['Category'] =='Movie')]
# Out:
#         Category                                Title  \
# Show_Id
# s7         Movie                                  122
# s104       Movie                    30 Days of Luxury
# s281       Movie                            Abdo Mota
# s372       Movie         Alarmoty in the Land of Fire
# s448       Movie                         Amar's Hands
# ...          ...                                  ...
# s7482      Movie                                Warda
# s7513      Movie  We'll Be Right Back After The Break
# s7684      Movie                              X Large
# s7749      Movie                            الف مبروك
# s7761      Movie                            Zaki Chan
#
#                                                       Cast Country  \
# Show_Id
# s7       Amina Khalil, Ahmed Dawood, Tarek Lotfy, Ahmed...   Egypt
# s104     Taher Farouz, Sad Al-Saghir, Ahmad Faloks, Sol...   Egypt
# s281                                       Mohamed Ramadan   Egypt
# ...

# %%
## show all categories where category is movie and type is comedy or country is  United Kindom 
data[(data['Category'] =='Movie')&(data['Type'].str.contains('Comedies')) |(data['Country'] =='United Kingdom')]
# Out:
#         Category                              Title  \
# Show_Id
# s19        Movie                             15-Aug
# s20        Movie                                '89
# s34        Movie                       #realityhigh
# s35        Movie                              #Roxy
# s37        Movie                            #Selfie
# ...          ...                                ...
# s7765      Movie                               Zero
# s7770      Movie           Zindagi Na Milegi Dobara
# s7773      Movie  Zipi & Zape y la Isla del Capitan
# s7779      Movie                         Zombieland
# s7782      Movie                               Zoom
#
#                                                       Cast         Country  \
# Show_Id
# s19      Rahul Pethe, Mrunmayee Deshpande, Adinath Koth...           India
# s20                     Lee Dixon, Ian Wright, Paul Merson  United Kingdom
# s34      Nesta Cooper, Kate Walsh, John Michael Higgins...   United States
# ...

# %%
data_new =data.dropna()

# %%
data_new[data_new['Cast'].str.contains('Tom Cruise')]
# Out:
#         Category     Title                                               Cast  \
# Show_Id
# s3861      Movie  Magnolia  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...
# s5071      Movie  Rain Man  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...
#
#                Country     Release_Date Rating Duration  \
# Show_Id
# s3861    United States  January 1, 2020      R  189 min
# s5071    United States     July 1, 2019      R  134 min
#
#                                Type  \
# Show_Id
# s3861    Dramas, Independent Movies
# s5071        Classic Movies, Dramas
#
#                                                Description     data-n  \
# Show_Id
# s3861    Through chance, human action, past history and... 2020-01-01
# s5071    A fast-talking yuppie is forced to slow down w... 2019-07-01
#
#             date-n    year
# Show_Id
# s3861   2020-01-01  2020.0
# s5071   2019-07-01  2019.0

# %%
data['Rating'].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'NR', 'TV-G', 'TV-Y', nan,
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
data.Rating.nunique() # number of unique values of Netflix Rating
# Out:
# 14

# %%
# How many movies got tv-14 of category movie 
data[(data['Category'] =='Movie')&(data['Rating'] =='TV-14')&(data['Country'] =='Canada')].shape
# Out:
# (11, 12)

# %%
# How many tv show got R rating after 2018
data[(data['Rating'] =='R') & (data['Category'] =='TV Show') &(data['year'] > 2018)]
# Out:
#         Category                                Title  \
# Show_Id
# s6436    TV Show  The Hateful Eight: Extended Version
#
#                                                       Cast Country  \
# Show_Id
# s6436    Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN
#
#            Release_Date Rating  Duration      Type  \
# Show_Id
# s6436    April 25, 2019      R  1 Season  TV Shows
#
#                                                Description     data-n  \
# Show_Id
# s6436    Trapped at a stagecoach stop as a storm rages ... 2019-04-25
#
#             date-n    year
# Show_Id
# s6436   2019-04-25  2019.0

# %% [markdown]
# ## Maximum duration on netflix movie

# %%
data.Duration.unique()
# Out:
# array(['4 Seasons', '93 min', '78 min', '80 min', '123 min', '1 Season',
#        '95 min', '119 min', '118 min', '143 min', '103 min', '89 min',
#        '91 min', '149 min', '144 min', '124 min', '87 min', '110 min',
#        '128 min', '117 min', '100 min', '2 Seasons', '84 min', '99 min',
#        '90 min', '102 min', '104 min', '105 min', '56 min', '125 min',
#        '81 min', '97 min', '106 min', '107 min', '109 min', '44 min',
#        '75 min', '101 min', '3 Seasons', '37 min', '113 min', '114 min',
#        '130 min', '94 min', '140 min', '135 min', '82 min', '70 min',
#        '121 min', '92 min', '164 min', '53 min', '83 min', '116 min',
#        '86 min', '120 min', '96 min', '126 min', '129 min', '77 min',
#        '137 min', '148 min', '28 min', '122 min', '176 min', '85 min',
#        '22 min', '68 min', '111 min', '29 min', '142 min', '168 min',
#        '21 min', '59 min', '20 min', '98 min', '108 min', '76 min',
# ...

# %%
data.head()
# Out:
#         Category  Title                                               Cast  \
# Show_Id
# s1       TV Show     3%  João Miguel, Bianca Comparato, Michel Gomes, R...
# s2         Movie  07:19  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# s3         Movie  23:59  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# s4         Movie      9  Elijah Wood, John C. Reilly, Jennifer Connelly...
# s5         Movie     21  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
#
#                Country       Release_Date Rating   Duration  \
# Show_Id
# s1              Brazil    August 14, 2020  TV-MA  4 Seasons
# s2              Mexico  December 23, 2016  TV-MA     93 min
# s3           Singapore  December 20, 2018      R     78 min
# s4       United States  November 16, 2017  PG-13     80 min
# s5       United States    January 1, 2020  PG-13    123 min
#
#                                                       Type  \
# Show_Id
# s1       International TV Shows, TV Dramas, TV Sci-Fi &...
# ...
